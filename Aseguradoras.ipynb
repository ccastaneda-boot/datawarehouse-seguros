# %% [markdown]
# <a href="https://colab.research.google.com/github/ccastaneda-boot/datawarehouse-seguros/blob/main/Aseguradoras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://raw.githubusercontent.com/ccastaneda-boot/datawarehouse-seguros/refs/heads/main/data/clientes.csv

# %%
url="https://raw.githubusercontent.com/ccastaneda-boot/datawarehouse-seguros/refs/heads/main/data/aseguradoras.csv"

# %%
#Adicionamos librería Panda
import pandas as pd

# %%
#Lectura del archivo
df = pd.read_csv(url)
print("Dataset Cargado Correctamente")
# Out:
# Dataset Cargado Correctamente

# %%
#Verificando cabecera del archivo.
display(df.head())
# Out:
#    id_aseguradora         nombre         pais rating_riesgo
# 0               1  Aseguradora 1   Costa Rica          Alto
# 1               2  Aseguradora 2  El Salvador          Bajo
# 2               3  Aseguradora 3  El Salvador           NaN
# 3               4  Aseguradora 4   Costa Rica         Medio
# 4               5  Aseguradora 5   ElSalvador             B

# %% [markdown]
# **BLOQUE 2: Exploracion del DATASET (Calidad del dato)**

# %%
print("Primeras filas del dataset")
display(df.head())
# Out:
# Primeras filas del dataset
#    id_aseguradora         nombre         pais rating_riesgo
# 0               1  Aseguradora 1   Costa Rica          Alto
# 1               2  Aseguradora 2  El Salvador          Bajo
# 2               3  Aseguradora 3  El Salvador           NaN
# 3               4  Aseguradora 4   Costa Rica         Medio
# 4               5  Aseguradora 5   ElSalvador             B

# %%
print("Dimensiones del dataset (filas, columnas)")
print(df.shape)
# Out:
# Dimensiones del dataset (filas, columnas)
# (15, 4)

# %%
print("Columnas del dataset")
print(df.columns)
# Out:
# Columnas del dataset
# Index(['id_aseguradora', 'nombre', 'pais', 'rating_riesgo'], dtype='object')

# %%
print("Tipo de datos")
print(df.dtypes)
# Out:
# Tipo de datos
# id_aseguradora     int64
# nombre            object
# pais              object
# rating_riesgo     object
# dtype: object

# %%
print("Valores nulos")
print(df.isnull().sum())
# Out:
# Valores nulos
# id_aseguradora    0
# nombre            0
# pais              2
# rating_riesgo     3
# dtype: int64

# %%
print ("valores duplicados")
print(df.duplicated().sum())
# Out:
# valores duplicados
# 0

# %% [markdown]
# **BLOQUE 3: LIMPIEZA DE DATOS**

# %%
#Elimina espacios al inicio y al final en columnas de texto
for col in df.select_dtypes(include="object").columns:df[col]=df[col].str.strip()

# %%
#Normalizar el nombre
df["nombre"]=df["nombre"].str.title()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1775/1518383253.py in <cell line: 0>()
#       1 #Normalizar el nombre
# ----> 2 df["nombre"]=df["nombre"].str.title()
#
# NameError: name 'df' is not defined
